# %% [markdown]
# # Training 3D U-Net model for multi-class semantic segmentation

# %% [markdown]
# ### Install pkgs

# %%
#!pip install git+https://github.com/copick/copick-utils.git matplotlib tqdm copick 
#!pip install -q "monai-weekly[mlflow]"
#!pip install git+https://github.com/copick/copick-utils.git

# %% [markdown]
# ### Copick configuration file template
#
# We will use a Polenet simulation dataset 10439 from the [CryoET Data Portal](https://cryoetdataportal.czscience.com) in this notebook. The dataset has 27 tomograms and 7 celluar structures. We will use [copick](https://copick.github.io/copick/) dataset API for handling cryoET datasets. Below is a copick configuration file detailing the dataset, and you can save it as a JSON file in your working directory.
#
# ```
# {
#     "config_type": "cryoet_data_portal",
#     "name": "polnet",
#     "description": "A Data Portal project.",
#     "version": "1.0.0",
#
#     "pickable_objects": [
#         {
#             "name": "membrane",
#             "is_particle": false,
#             "label": 1,
#             "go_id": "GO:0016020",
#             "color": [150,150, 150, 255],
#             "radius": 10
#         },
#         {
#             "name": "adp-mitochondrial",
#             "is_particle": true,
#             "pdb_id": "6MRD",
#             "go_id": "GO:1990220",
#             "label": 2,
#             "color": [  0, 117, 220, 255],
#             "radius": 75,
#             "map_threshold": 0.037
#         },
#         {
#             "name": "alkaline-phosphate",
#             "is_particle": true,
#             "pdb_id": "1ZEF",
#             "go_id": "UniProtKB:P05187",
#             "label": 3,
#             "color": [  0, 117, 220, 255],
#             "radius": 75,
#             "map_threshold": 0.037
#         },
#         {
#             "name": "nucleosome",
#             "is_particle": true,
#             "pdb_id": "6UPH",
#             "go_id": "GO:0000786",
#             "label": 4,
#             "color": [  0, 117, 220, 255],
#             "radius": 65,
#             "map_threshold": 0.037
#         },
#         {
#             "name": "ribosome",
#             "is_particle": true,
#             "pdb_id": "7TM3",
#             "go_id": "GO:0022626",
#             "label": 5,
#             "color": [  0, 117, 220, 255],
#             "radius": 165,
#             "map_threshold": 0.037
#         },
#         {
#             "name": "vault",
#             "is_particle": true,
#             "pdb_id": "7PKZ",
#             "go_id": "UniProtKB:Q62667",
#             "label": 6,
#             "color": [  0, 117, 220, 255],
#             "radius": 165,
#             "map_threshold": 0.037
#         },
#         {
#             "name": "virus-like-capsid",
#             "is_particle": true,
#             "pdb_id": "6NK5",
#             "go_id": "GO:0170047",
#             "label": 7,
#             "color": [  0, 117, 220, 255],
#             "radius": 140,
#             "map_threshold": 0.037
#         }
#     ],
#
#     "overlay_root": "LOCAL_PATH",
#
#     "overlay_fs_args": {
#         "auto_mkdir": true
#     },
#
#     "dataset_ids": [10439]
# }
#
# ```

# %%
import os
import numpy as np
from pathlib import Path
import torch
import torchinfo
import zarr, copick
from tqdm import tqdm
from monai.config import print_config
from monai.data import DataLoader, CacheDataset, MetaTensor, decollate_batch
from monai.transforms import (
    Compose, 
    EnsureChannelFirstd, 
    ScaleIntensityRanged, 
    CropForegroundd, 
    Orientationd, 
    Spacingd, 
    EnsureTyped, 
    Activations, 
    AsDiscrete, 
    Resized, 
    RandFlipd, 
    RandRotate90d, 
    RandZoomd,
    RandGridPatchd,
    NormalizeIntensityd,
    RandCropByLabelClassesd,
    Resized, 
    RandZoomd,
    Activations, 
    CropForegroundd, 
    ScaleIntensityRanged, 
    RandCropByPosNegLabeld,    
)
from monai.networks.nets import UNet, DynUNet
from monai.losses import DiceLoss, FocalLoss, TverskyLoss
from monai.metrics import DiceMetric, ConfusionMatrixMetric
from skimage
import mlflow
import mlflow.pytorch
from sklearn.model_selection import train_test_split

from monai.transforms import Compose, EnsureChannelFirstd, NormalizeIntensityd, Orientationd, RandCropByLabelClassesd, RandRotate90d, RandFlipd
from monai.data import CacheDataset, DataLoader, Dataset
import torch
# Out:
# 2024-10-01 23:28:21.909123: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-01 23:28:31.722382: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-01 23:28:32.511742: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-01 23:28:32.900635: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-01 23:28:35.456879: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-01 23:29:04.689741: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Prepare the dataset

# %% [markdown]
# ### 1. Get copick root

# %%
copick_config_path = "config_10439.json"
root = copick.from_file(copick_config_path)

# %% [markdown]
# ### 3. Get tomograms and their segmentaion masks (from picks) arrays
#
# This 10439 dataset contains 27 tomograms. We will use the first 5 tomograms for training, and the following 2 tomograms for validation. Therefore, we will get the first 7 tomograms from the cryoET data portal in this notebook, and we will use the rest 20 tomograms for inference in a different notebook.

# %%
def get_tomogram_array(copick_run, voxel_spacing=10, tomo_type='wbp'):
    voxel_spacing_obj = copick_run.get_voxel_spacing(voxel_spacing)
    tomogram = voxel_spacing_obj.get_tomogram(tomo_type)
    image = zarr.open(tomogram.zarr(), mode='r')['0']
    return image[:]

def get_segmentation_array(copick_run, segmentation_name, voxel_spacing=10, is_multilabel=True):
    #seg_memb = copick_run.get_segmentations(name="membrane")
    seg_memb = copick_run.get_segmentations()
    seg = copick_run.get_segmentations(is_multilabel=is_multilabel, name=segmentation_name, voxel_size=voxel_spacing)
    if len(seg) == 0:
        raise ValueError(f"No segmentations found for session '{session_id}' and segmentation type '{segmentation_type}'.")
        
    segmentation = zarr.open(seg[0].zarr().path, mode="r")['0'][:]
    _, array = list(zarr.open(seg_memb[0].zarr()).arrays())[0]
    seg_membrane = np.array(array[:])
    #seg_membrane = zarr.open(seg_memb[0].zarr().path, mode="r")['0'][:]
    segmentation[seg_membrane==1] = 1
    return segmentation

# %%
voxel_spacing = 5 
tomo_type = "wbp"
painting_segmentation_name = "remotetargets" #"remotetargets"

data_dicts = []
for run in tqdm(root.runs[:5]):
    tomogram = get_tomogram_array(run)
    segmentation = get_segmentation_array(run, painting_segmentation_name)
    data_dicts.append({"image": tomogram, "label": segmentation})
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:59<00:00, 11.90s/it]

# %%
voxel_spacing = 10
tomo_type = "wbp"
painting_segmentation_name = "remotetargets" #"remotetargets"

runIDs = np.arange(16175,16190)
data_dicts = []
for runID in tqdm(runIDs):
    run = root.get_run(str(runID))
    tomogram = get_tomogram_array(run)
    segmentation = get_segmentation_array(run, painting_segmentation_name)
    data_dicts.append({"image": tomogram, "label": segmentation})
# Out:
# 100%|███████████████████████████████████████████| 15/15 [02:40<00:00, 10.70s/it]

# %% [markdown]
# Since memebranes do not have picks, we should see 6 distinct labels for particles, with 0 being the default background label.

# %% [markdown]
# ### 4. Visualize the tomogram and painted segmentation from ground-truth picks

# %%
import matplotlib.pyplot as plt

# Plot the images
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.title('Tomogram')
plt.imshow(data_dicts[0]['image'][90],cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Painted Segmentation from Picks')
plt.imshow(data_dicts[0]['label'][90], cmap='viridis')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Prepare dataloaders

# %%
my_num_samples = 16
train_batch_size = 1
val_batch_size = 1

test_files = data_dicts[-2:]
train_files, val_files = train_test_split(data_dicts[:-2], test_size=0.3)
print(f"Number of training samples: {len(train_files)}")
print(f"Number of validation samples: {len(val_files)}")

# Non-random transforms to be cached
non_random_transforms = Compose([
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    NormalizeIntensityd(keys="image"),
    Orientationd(keys=["image", "label"], axcodes="RAS")
])

# Random transforms to be applied during training
random_transforms = Compose([
    RandCropByLabelClassesd(
        keys=["image", "label"],
        label_key="label",
        spatial_size=[96, 96, 96],
        num_classes=8,
        num_samples=my_num_samples
    ),
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[0, 2]),
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),    
])

# Create the cached dataset with non-random transforms
train_ds = CacheDataset(data=train_files, transform=non_random_transforms, cache_rate=1.0)

# Wrap the cached dataset to apply random transforms during iteration
train_ds = Dataset(data=train_ds, transform=random_transforms)

# DataLoader remains the same
train_loader = DataLoader(
    train_ds,
    batch_size=train_batch_size,
    shuffle=True,
    num_workers=4,
    pin_memory=torch.cuda.is_available()
)

# Validation transforms
val_transforms = Compose([
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    NormalizeIntensityd(keys="image"),
    RandCropByLabelClassesd(
        keys=["image", "label"],
        label_key="label",
        spatial_size=[96, 96, 96],
        num_classes=8,
        num_samples=my_num_samples,  # Use 1 to get a single, consistent crop per image
    ),
])

# Create validation dataset
val_ds = CacheDataset(data=val_files, transform=non_random_transforms, cache_rate=1.0)

# Wrap the cached dataset to apply random transforms during iteration
val_ds = Dataset(data=val_ds, transform=random_transforms)

# Create validation DataLoader
val_loader = DataLoader(
    val_ds,
    batch_size=val_batch_size,
    num_workers=4,
    pin_memory=torch.cuda.is_available(),
    shuffle=False,  # Ensure the data order remains consistent
)
# Out:
# Number of training samples: 9
# Number of validation samples: 4
# Loading dataset: 100%|████████████████████████████| 9/9 [00:02<00:00,  4.14it/s]
# /hpc/projects/group.czii/jonathan.schwartz/2024_czii_mlchallenge_notebooks/pyUNET/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Loading dataset: 100%|████████████████████████████| 4/4 [00:00<00:00,  5.88it/s]

# %% [markdown]
# ## Model setup

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Create UNet, DiceLoss and Adam optimizer
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=len(root.pickable_objects)+1,
    channels=(48, 64, 80, 80),
    strides=(2, 2, 1),
    num_res_units=1,
).to(device)

lr = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr)
#loss_function = DiceLoss(include_background=True, to_onehot_y=True, softmax=True)  # softmax=True for multiclass
loss_function = TverskyLoss(include_background=True, to_onehot_y=True, softmax=True)  

dice_metric = DiceMetric(include_background=False, reduction="mean", ignore_empty=True)  # must use onehot for multiclass
recall_metric = ConfusionMatrixMetric(include_background=False, metric_name="recall", reduction="None")
# Out:
# cuda

# %%
from monai.inferers import sliding_window_inference

def stack_patches(data):
    shape = data.shape
    new_shape = (shape[0] * shape[1],) + shape[2:]
    return data.view(new_shape)

post_pred = AsDiscrete(argmax=True, to_onehot=len(root.pickable_objects)+1)
post_label = AsDiscrete(to_onehot=len(root.pickable_objects)+1)

def train(train_loader, model, loss_function, metrics_function, optimizer, max_epochs=100):
    val_interval = 2
    best_metric = -1
    best_metric_epoch = -1
    epoch_loss_values = []
    metric_values = []
    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{max_epochs}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            step += 1
            inputs = batch_data["image"].to(device)  # Shape: [B, C, H, W, D]
            labels = batch_data["label"].to(device)  # Shape: [B, C, H, W, D]            
            optimizer.zero_grad()
            outputs = model(inputs)    # Output shape: [B, num_classes, H, W, D]
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            print(f"batch {step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
        epoch_loss /= step
        epoch_loss_values.append(epoch_loss)
        print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
        mlflow.log_metric("train_loss", epoch_loss, step=epoch+1)

        if (epoch + 1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                for val_data in val_loader:
                    val_inputs = val_data["image"].to(device)
                    val_labels = val_data["label"].to(device)
                    val_outputs = model(val_inputs)
                    
                    # Decollate batches into lists
                    val_outputs_list = decollate_batch(val_outputs)
                    val_labels_list = decollate_batch(val_labels)
                    # Apply post-processing
                    metric_val_outputs = [post_pred(i) for i in val_outputs_list]
                    metric_val_labels = [post_label(i) for i in val_labels_list]
                    # Compute metrics
                    metrics_function(y_pred=metric_val_outputs, y=metric_val_labels)

                metrics = metrics_function.aggregate(reduction="mean_batch")
                metric_per_class = ["{:.4g}".format(x) for x in metrics]
                metric = torch.mean(metrics).numpy(force=True)
                mlflow.log_metric("validation metric", metric, step=epoch+1)
                for i,m in enumerate(metrics):
                    mlflow.log_metric(f"validation metric class {i+1}", m, step=epoch+1)
                metrics_function.reset()

                metric_values.append(metric)
                if metric > best_metric:
                    best_metric = metric
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join('./', "best_metric_model.pth"))
                    
                    print("saved new best metric model")
                print(
                    f"current epoch: {epoch + 1} current mean recall per class: {', '.join(metric_per_class)}"
                    f"\nbest mean recall: {best_metric:.4f} "
                    f"at epoch: {best_metric_epoch}"
                )

# %% [markdown]
# ## Training and tracking

# %%
from torchinfo import summary

mlflow.end_run()
mlflow.set_experiment('training 3D U-Net model for the cryoET ML Challenge')
epochs = 200
with mlflow.start_run():
    params = {
        "epochs": epochs,
        "learning_rate": lr,
        "loss_function": loss_function.__class__.__name__,
        "metric_function": recall_metric.__class__.__name__,
        "optimizer": "Adam",
    }
    # Log training parameters.
    mlflow.log_params(params)

    # Log model summary.
    with open("model_summary.txt", "w") as f:
        f.write(str(summary(model)))
    mlflow.log_artifact("model_summary.txt")

    train(train_loader, model, loss_function, dice_metric, optimizer, max_epochs=epochs)

    # Save the trained model to MLflow.
    mlflow.pytorch.log_model(model, "model")
# Out:
# ----------
# epoch 1/200
# /hpc/projects/group.czii/jonathan.schwartz/2024_czii_mlchallenge_notebooks/pyUNET/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# batch 1/9, train_loss: 0.9595
# batch 2/9, train_loss: 0.9524
# batch 3/9, train_loss: 0.9431
# batch 4/9, train_loss: 0.9343
# batch 5/9, train_loss: 0.9349
# batch 6/9, train_loss: 0.9271
# batch 7/9, train_loss: 0.9254
# batch 8/9, train_loss: 0.9196
# batch 9/9, train_loss: 0.9135
# epoch 1 average loss: 0.9344
# ----------
# epoch 2/200
# batch 1/9, train_loss: 0.9113
# batch 2/9, train_loss: 0.9086
# batch 3/9, train_loss: 0.9089
# batch 4/9, train_loss: 0.8981
# batch 5/9, train_loss: 0.8920
# batch 6/9, train_loss: 0.9004
# batch 7/9, train_loss: 0.8844
# batch 8/9, train_loss: 0.8904
# batch 9/9, train_loss: 0.8912
# epoch 2 average loss: 0.8984
# saved new best metric model
# current epoch: 2 current mean recall per class: 0.01426, 0.01126, 0.05382, 0.02512, 0.3477, 0.02237, 0.01565
# best mean recall: 0.0700 at epoch: 2
# ----------
# epoch 3/200
# batch 1/9, train_loss: 0.8863
# batch 2/9, train_loss: 0.8757
# batch 3/9, train_loss: 0.8740
# batch 4/9, train_loss: 0.8800
# batch 5/9, train_loss: 0.8782
# batch 6/9, train_loss: 0.8706
# batch 7/9, train_loss: 0.8743
# batch 8/9, train_loss: 0.8701
# batch 9/9, train_loss: 0.8757
# epoch 3 average loss: 0.8761
# ----------
# epoch 4/200
# batch 1/9, train_loss: 0.8560
# batch 2/9, train_loss: 0.8599
# batch 3/9, train_loss: 0.8543
# batch 4/9, train_loss: 0.8866
# batch 5/9, train_loss: 0.8614
# batch 6/9, train_loss: 0.8498
# batch 7/9, train_loss: 0.8534
# batch 8/9, train_loss: 0.8466
# batch 9/9, train_loss: 0.8512
# epoch 4 average loss: 0.8577
# saved new best metric model
# current epoch: 4 current mean recall per class: 0.06487, 0.003589, 0.08275, 0.04811, 0.5268, 0.01967, 0.002182
# best mean recall: 0.1069 at epoch: 4
# ----------
# epoch 5/200
# batch 1/9, train_loss: 0.8519
# batch 2/9, train_loss: 0.8429
# batch 3/9, train_loss: 0.8490
# batch 4/9, train_loss: 0.8363
# batch 5/9, train_loss: 0.8591
# batch 6/9, train_loss: 0.8320
# batch 7/9, train_loss: 0.8317
# batch 8/9, train_loss: 0.8583
# batch 9/9, train_loss: 0.8367
# epoch 5 average loss: 0.8442
# ----------
# epoch 6/200
# batch 1/9, train_loss: 0.8357
# batch 2/9, train_loss: 0.8497
# batch 3/9, train_loss: 0.8301
# batch 4/9, train_loss: 0.8255
# batch 5/9, train_loss: 0.8342
# batch 6/9, train_loss: 0.8150
# batch 7/9, train_loss: 0.8053
# batch 8/9, train_loss: 0.8190
# batch 9/9, train_loss: 0.7986
# epoch 6 average loss: 0.8237
# saved new best metric model
# current epoch: 6 current mean recall per class: 0.04689, 0.005879, 0.2164, 0.1094, 0.5901, 0, 0
# best mean recall: 0.1384 at epoch: 6
# ----------
# epoch 7/200
# batch 1/9, train_loss: 0.8175
# batch 2/9, train_loss: 0.8246
# batch 3/9, train_loss: 0.8364
# batch 4/9, train_loss: 0.8082
# batch 5/9, train_loss: 0.7984
# batch 6/9, train_loss: 0.8038
# batch 7/9, train_loss: 0.8068
# batch 8/9, train_loss: 0.7952
# batch 9/9, train_loss: 0.8284
# epoch 7 average loss: 0.8133
# ----------
# epoch 8/200
# batch 1/9, train_loss: 0.8074
# batch 2/9, train_loss: 0.8079
# batch 3/9, train_loss: 0.8217
# batch 4/9, train_loss: 0.8410
# batch 5/9, train_loss: 0.7937
# batch 6/9, train_loss: 0.7882
# batch 7/9, train_loss: 0.8044
# batch 8/9, train_loss: 0.7992
# batch 9/9, train_loss: 0.7926
# epoch 8 average loss: 0.8062
# current epoch: 8 current mean recall per class: 0.03898, 0.03861, 0.2562, 0.145, 0.4746, 0, 0
# best mean recall: 0.1384 at epoch: 6
# ----------
# epoch 9/200
# batch 1/9, train_loss: 0.8029
# batch 2/9, train_loss: 0.7891
# batch 3/9, train_loss: 0.7926
# batch 4/9, train_loss: 0.7784
# batch 5/9, train_loss: 0.8113
# batch 6/9, train_loss: 0.8478
# batch 7/9, train_loss: 0.7828
# batch 8/9, train_loss: 0.7692
# batch 9/9, train_loss: 0.7811
# epoch 9 average loss: 0.7950
# ----------
# epoch 10/200
# batch 1/9, train_loss: 0.7847
# batch 2/9, train_loss: 0.7914
# batch 3/9, train_loss: 0.7642
# batch 4/9, train_loss: 0.7782
# batch 5/9, train_loss: 0.7642
# batch 6/9, train_loss: 0.7887
# batch 7/9, train_loss: 0.7700
# batch 8/9, train_loss: 0.7836
# batch 9/9, train_loss: 0.8309
# epoch 10 average loss: 0.7840
# saved new best metric model
# current epoch: 10 current mean recall per class: 0.02542, 0.07975, 0.3072, 0.2665, 0.5649, 0, 0
# best mean recall: 0.1777 at epoch: 10
# ----------
# epoch 11/200
# batch 1/9, train_loss: 0.8285
# batch 2/9, train_loss: 0.7860
# batch 3/9, train_loss: 0.7821
# batch 4/9, train_loss: 0.7708
# batch 5/9, train_loss: 0.7496
# batch 6/9, train_loss: 0.7680
# batch 7/9, train_loss: 0.7996
# batch 8/9, train_loss: 0.8009
# batch 9/9, train_loss: 0.7772
# epoch 11 average loss: 0.7847
# ----------
# epoch 12/200
# batch 1/9, train_loss: 0.7606
# batch 2/9, train_loss: 0.7369
# batch 3/9, train_loss: 0.7376
# batch 4/9, train_loss: 0.7678
# batch 5/9, train_loss: 0.7493
# batch 6/9, train_loss: 0.7498
# batch 7/9, train_loss: 0.8268
# current epoch: 18 current mean recall per class: 0.1629, 0.173, 0.4933, 0.3806, 0.5199, 0, 0
# best mean recall: 0.2471 at epoch: 18
# ----------
# epoch 19/200
# batch 1/9, train_loss: 0.7251
# batch 2/9, train_loss: 0.7047
# batch 3/9, train_loss: 0.7187
# batch 4/9, train_loss: 0.7164
# batch 5/9, train_loss: 0.7501
# batch 6/9, train_loss: 0.7230
# batch 7/9, train_loss: 0.7052
# batch 8/9, train_loss: 0.8171
# batch 9/9, train_loss: 0.7152
# epoch 19 average loss: 0.7306
# ----------
# epoch 20/200
# batch 1/9, train_loss: 0.8156
# batch 2/9, train_loss: 0.6990
# batch 3/9, train_loss: 0.7476
# batch 4/9, train_loss: 0.6934
# batch 5/9, train_loss: 0.7252
# batch 6/9, train_loss: 0.7076
# batch 7/9, train_loss: 0.7180
# batch 8/9, train_loss: 0.7236
# batch 9/9, train_loss: 0.7102
# epoch 20 average loss: 0.7267
# saved new best metric model
# current epoch: 20 current mean recall per class: 0.1889, 0.1482, 0.4962, 0.416, 0.5764, 0, 0
# best mean recall: 0.2608 at epoch: 20
# ----------
# epoch 21/200
# batch 1/9, train_loss: 0.7057
# batch 2/9, train_loss: 0.8121
# batch 3/9, train_loss: 0.7397
# batch 4/9, train_loss: 0.7270
# batch 5/9, train_loss: 0.7342
# batch 6/9, train_loss: 0.7090
# batch 7/9, train_loss: 0.7118
# batch 8/9, train_loss: 0.7707
# batch 9/9, train_loss: 0.7245
# epoch 21 average loss: 0.7372
# ----------
# epoch 22/200
# batch 1/9, train_loss: 0.7349
# batch 2/9, train_loss: 0.7028
# batch 3/9, train_loss: 0.7016
# batch 4/9, train_loss: 0.7288
# batch 5/9, train_loss: 0.6945
# batch 6/9, train_loss: 0.7364
# batch 7/9, train_loss: 0.8279
# batch 8/9, train_loss: 0.6766
# batch 9/9, train_loss: 0.7046
# epoch 22 average loss: 0.7231
# saved new best metric model
# current epoch: 22 current mean recall per class: 0.2728, 0.2915, 0.5724, 0.3709, 0.6079, 0, 0
# best mean recall: 0.3022 at epoch: 22
# ----------
# epoch 23/200
# batch 1/9, train_loss: 0.7037
# batch 2/9, train_loss: 0.6643
# batch 3/9, train_loss: 0.7214
# batch 4/9, train_loss: 0.7065
# batch 5/9, train_loss: 0.7052
# batch 6/9, train_loss: 0.6736
# batch 7/9, train_loss: 0.6901
# batch 8/9, train_loss: 0.8317
# batch 9/9, train_loss: 0.6908
# epoch 23 average loss: 0.7097
# ----------
# epoch 24/200
# batch 1/9, train_loss: 0.6806
# batch 2/9, train_loss: 0.7428
# batch 3/9, train_loss: 0.6747
# batch 4/9, train_loss: 0.6760
# batch 5/9, train_loss: 0.8177
# batch 6/9, train_loss: 0.6962
# batch 7/9, train_loss: 0.6855
# batch 8/9, train_loss: 0.6905
# batch 9/9, train_loss: 0.7010
# epoch 24 average loss: 0.7072
# saved new best metric model
# current epoch: 24 current mean recall per class: 0.3746, 0.3645, 0.558, 0.5191, 0.6648, 0, 0
# best mean recall: 0.3544 at epoch: 24
# ----------
# epoch 25/200
# epoch 37 average loss: 0.6498
# ----------
# epoch 38/200
# batch 1/9, train_loss: 0.6528
# batch 2/9, train_loss: 0.8141
# batch 3/9, train_loss: 0.6410
# batch 4/9, train_loss: 0.6553
# batch 5/9, train_loss: 0.6300
# batch 6/9, train_loss: 0.5820
# batch 7/9, train_loss: 0.6213
# batch 8/9, train_loss: 0.6242
# batch 9/9, train_loss: 0.6490
# epoch 38 average loss: 0.6522
# current epoch: 38 current mean recall per class: 0.2936, 0.5764, 0.627, 0.4343, 0.6094, 0.3848, 0.2706
# best mean recall: 0.4783 at epoch: 36
# ----------
# epoch 39/200
# batch 1/9, train_loss: 0.6066
# batch 2/9, train_loss: 0.6804
# batch 3/9, train_loss: 0.6330
# batch 4/9, train_loss: 0.8151
# batch 5/9, train_loss: 0.6270
# batch 6/9, train_loss: 0.6456
# batch 7/9, train_loss: 0.6373
# batch 8/9, train_loss: 0.6082
# batch 9/9, train_loss: 0.6319
# epoch 39 average loss: 0.6539
# ----------
# epoch 40/200
# batch 1/9, train_loss: 0.6490
# batch 2/9, train_loss: 0.6479
# batch 3/9, train_loss: 0.5922
# batch 4/9, train_loss: 0.6050
# batch 5/9, train_loss: 0.6271
# batch 6/9, train_loss: 0.6045
# batch 7/9, train_loss: 0.5861
# batch 8/9, train_loss: 0.5852
# batch 9/9, train_loss: 0.8197
# epoch 40 average loss: 0.6352
# saved new best metric model
# current epoch: 40 current mean recall per class: 0.3734, 0.6563, 0.666, 0.5286, 0.707, 0.4737, 0.1271
# best mean recall: 0.5046 at epoch: 40
# ----------
# epoch 41/200
# batch 1/9, train_loss: 0.6313
# batch 2/9, train_loss: 0.6198
# batch 3/9, train_loss: 0.7955
# batch 4/9, train_loss: 0.6429
# batch 5/9, train_loss: 0.5887
# batch 6/9, train_loss: 0.5870
# batch 7/9, train_loss: 0.6139
# batch 8/9, train_loss: 0.6093
# batch 9/9, train_loss: 0.6066
# epoch 41 average loss: 0.6328
# ----------
# epoch 42/200
# batch 1/9, train_loss: 0.8029
# batch 2/9, train_loss: 0.6416
# batch 3/9, train_loss: 0.5833
# batch 4/9, train_loss: 0.6455
# batch 5/9, train_loss: 0.6148
# batch 6/9, train_loss: 0.6418
# batch 7/9, train_loss: 0.5727
# batch 8/9, train_loss: 0.5821
# batch 9/9, train_loss: 0.6349
# epoch 42 average loss: 0.6355
# saved new best metric model
# current epoch: 42 current mean recall per class: 0.4158, 0.5585, 0.6038, 0.4913, 0.6093, 0.442, 0.4195
# best mean recall: 0.5057 at epoch: 42
# ----------
# epoch 43/200
# batch 1/9, train_loss: 0.6312
# batch 2/9, train_loss: 0.5575
# batch 3/9, train_loss: 0.5901
# batch 4/9, train_loss: 0.5855
# batch 5/9, train_loss: 0.6540
# batch 6/9, train_loss: 0.6441
# batch 7/9, train_loss: 0.8147
# batch 8/9, train_loss: 0.6386
# batch 9/9, train_loss: 0.6412
# epoch 43 average loss: 0.6397
# ----------
# epoch 44/200
# batch 1/9, train_loss: 0.6054
# batch 2/9, train_loss: 0.6153
# batch 3/9, train_loss: 0.6041
# batch 4/9, train_loss: 0.8106
# batch 5/9, train_loss: 0.6262
# batch 6/9, train_loss: 0.6239
# batch 7/9, train_loss: 0.6096
# batch 8/9, train_loss: 0.6001
# batch 9/9, train_loss: 0.5779
# epoch 44 average loss: 0.6303
# saved new best metric model
# current epoch: 44 current mean recall per class: 0.3744, 0.6005, 0.6369, 0.5189, 0.6278, 0.4832, 0.5406
# best mean recall: 0.5403 at epoch: 44
# ----------
# epoch 45/200
# batch 1/9, train_loss: 0.6008
# batch 2/9, train_loss: 0.5768
# batch 3/9, train_loss: 0.5874
# batch 4/9, train_loss: 0.6208
# batch 5/9, train_loss: 0.6139
# batch 6/9, train_loss: 0.6304
# batch 7/9, train_loss: 0.8161
# batch 8/9, train_loss: 0.6301
# batch 9/9, train_loss: 0.6053
# epoch 45 average loss: 0.6313
# ----------
# epoch 46/200
# batch 1/9, train_loss: 0.6285
# batch 2/9, train_loss: 0.6325
# batch 3/9, train_loss: 0.6001
# batch 4/9, train_loss: 0.6461
# batch 5/9, train_loss: 0.5756
# batch 6/9, train_loss: 0.5983
# batch 7/9, train_loss: 0.5822
# batch 8/9, train_loss: 0.8029
# batch 9/9, train_loss: 0.6268
# epoch 46 average loss: 0.6326
# saved new best metric model
# current epoch: 46 current mean recall per class: 0.3792, 0.5891, 0.6358, 0.4852, 0.6896, 0.4961, 0.5174
# best mean recall: 0.5418 at epoch: 46
# ----------
# epoch 47/200
# batch 1/9, train_loss: 0.5718
# batch 2/9, train_loss: 0.5545
# batch 3/9, train_loss: 0.5986
# batch 4/9, train_loss: 0.6268
# batch 5/9, train_loss: 0.5868
# batch 6/9, train_loss: 0.5587
# batch 7/9, train_loss: 0.8021
# batch 8/9, train_loss: 0.5865
# batch 9/9, train_loss: 0.6002
# epoch 47 average loss: 0.6096
# ----------
# epoch 48/200
# batch 1/9, train_loss: 0.5302
# batch 2/9, train_loss: 0.5906
# batch 3/9, train_loss: 0.6130
# batch 4/9, train_loss: 0.6106
# batch 5/9, train_loss: 0.6083
# batch 6/9, train_loss: 0.7806
# batch 7/9, train_loss: 0.5956
# batch 8/9, train_loss: 0.6077
# batch 9/9, train_loss: 0.5798
# epoch 48 average loss: 0.6129
# saved new best metric model
# current epoch: 48 current mean recall per class: 0.4706, 0.6351, 0.5979, 0.4971, 0.6489, 0.6149, 0.6533
# best mean recall: 0.5883 at epoch: 48
# ----------
# epoch 49/200
# batch 1/9, train_loss: 0.5666
# batch 2/9, train_loss: 0.5725
# batch 3/9, train_loss: 0.6033
# batch 4/9, train_loss: 0.5914
# batch 5/9, train_loss: 0.6076
# batch 6/9, train_loss: 0.5546
# batch 7/9, train_loss: 0.8128
# batch 8/9, train_loss: 0.6345
# batch 9/9, train_loss: 0.6090
# epoch 49 average loss: 0.6169
# ----------
# epoch 50/200
# batch 1/9, train_loss: 0.5771
# batch 2/9, train_loss: 0.5696
# batch 3/9, train_loss: 0.5818
# batch 4/9, train_loss: 0.6134
# batch 5/9, train_loss: 0.5944
# epoch 56 average loss: 0.6048
# current epoch: 56 current mean recall per class: 0.377, 0.5893, 0.6676, 0.5011, 0.6892, 0.6195, 0.5094
# best mean recall: 0.5883 at epoch: 48
# ----------
# epoch 57/200
# batch 1/9, train_loss: 0.5826
# batch 2/9, train_loss: 0.5697
# batch 3/9, train_loss: 0.5355
# batch 4/9, train_loss: 0.6090
# batch 5/9, train_loss: 0.7888
# batch 6/9, train_loss: 0.6139
# batch 7/9, train_loss: 0.5704
# batch 8/9, train_loss: 0.5795
# batch 9/9, train_loss: 0.5983
# epoch 57 average loss: 0.6053
# ----------
# epoch 58/200
# batch 1/9, train_loss: 0.5284
# batch 2/9, train_loss: 0.5683
# batch 3/9, train_loss: 0.5450
# batch 4/9, train_loss: 0.7985
# batch 5/9, train_loss: 0.5539
# batch 6/9, train_loss: 0.6413
# batch 7/9, train_loss: 0.5546
# batch 8/9, train_loss: 0.5423
# batch 9/9, train_loss: 0.5868
# epoch 58 average loss: 0.5910
# current epoch: 58 current mean recall per class: 0.3846, 0.6091, 0.6579, 0.5355, 0.6693, 0.4694, 0.679
# best mean recall: 0.5883 at epoch: 48
# ----------
# epoch 59/200
# batch 1/9, train_loss: 0.6071
# batch 2/9, train_loss: 0.5550
# batch 3/9, train_loss: 0.5722
# batch 4/9, train_loss: 0.5780
# batch 5/9, train_loss: 0.5917
# batch 6/9, train_loss: 0.7830
# batch 7/9, train_loss: 0.5989
# batch 8/9, train_loss: 0.5682
# batch 9/9, train_loss: 0.5364
# epoch 59 average loss: 0.5989
# ----------
# epoch 60/200
# batch 1/9, train_loss: 0.6066
# batch 2/9, train_loss: 0.5843
# batch 3/9, train_loss: 0.6060
# batch 4/9, train_loss: 0.6051
# batch 5/9, train_loss: 0.7700
# batch 6/9, train_loss: 0.5587
# batch 7/9, train_loss: 0.5620
# batch 8/9, train_loss: 0.5602
# batch 9/9, train_loss: 0.5933
# epoch 60 average loss: 0.6051
# saved new best metric model
# current epoch: 60 current mean recall per class: 0.4282, 0.6408, 0.6913, 0.5445, 0.7078, 0.6039, 0.7651
# best mean recall: 0.6259 at epoch: 60
# ----------
# epoch 61/200
# batch 1/9, train_loss: 0.5711
# batch 2/9, train_loss: 0.5774
# batch 3/9, train_loss: 0.5617
# batch 4/9, train_loss: 0.5710
# batch 5/9, train_loss: 0.5949
# batch 6/9, train_loss: 0.5582
# batch 7/9, train_loss: 0.5764
# batch 8/9, train_loss: 0.5856
# batch 9/9, train_loss: 0.7943
# epoch 61 average loss: 0.5990
# ----------
# epoch 62/200
# batch 1/9, train_loss: 0.5855
# batch 2/9, train_loss: 0.5874
# batch 3/9, train_loss: 0.5685
# batch 4/9, train_loss: 0.5739
# batch 5/9, train_loss: 0.5910
# batch 6/9, train_loss: 0.5410
# batch 7/9, train_loss: 0.5694
# batch 8/9, train_loss: 0.5710
# batch 9/9, train_loss: 0.7565
# epoch 62 average loss: 0.5938
# current epoch: 62 current mean recall per class: 0.4364, 0.6768, 0.6533, 0.5449, 0.6935, 0.5452, 0.6678
# best mean recall: 0.6259 at epoch: 60
# ----------
# epoch 63/200
# batch 1/9, train_loss: 0.5275
# batch 2/9, train_loss: 0.6188
# batch 3/9, train_loss: 0.5714
# batch 4/9, train_loss: 0.5491
# batch 5/9, train_loss: 0.5985
# batch 6/9, train_loss: 0.7722
# batch 7/9, train_loss: 0.6131
# batch 8/9, train_loss: 0.5728
# batch 9/9, train_loss: 0.5708
# epoch 63 average loss: 0.5994
# ----------
# epoch 64/200
# batch 1/9, train_loss: 0.5391
# batch 2/9, train_loss: 0.5611
# batch 3/9, train_loss: 0.5615
# batch 4/9, train_loss: 0.5368
# batch 5/9, train_loss: 0.5463
# batch 6/9, train_loss: 0.5700
# batch 7/9, train_loss: 0.5643
# batch 8/9, train_loss: 0.5806
# batch 9/9, train_loss: 0.7930
# epoch 64 average loss: 0.5836
# current epoch: 64 current mean recall per class: 0.3846, 0.6225, 0.683, 0.5114, 0.7349, 0.583, 0.605
# best mean recall: 0.6259 at epoch: 60
# ----------
# epoch 65/200
# batch 1/9, train_loss: 0.5593
# batch 2/9, train_loss: 0.5687
# batch 3/9, train_loss: 0.5843
# batch 4/9, train_loss: 0.6057
# batch 5/9, train_loss: 0.5830
# batch 6/9, train_loss: 0.8037
# batch 7/9, train_loss: 0.5618
# batch 8/9, train_loss: 0.6002
# batch 9/9, train_loss: 0.5344
# epoch 65 average loss: 0.6001
# ----------
# epoch 66/200
# batch 1/9, train_loss: 0.5752
# batch 2/9, train_loss: 0.5692
# batch 3/9, train_loss: 0.7661
# batch 4/9, train_loss: 0.5436
# batch 5/9, train_loss: 0.5787
# batch 6/9, train_loss: 0.5986
# batch 7/9, train_loss: 0.5342
# batch 8/9, train_loss: 0.5552
# batch 9/9, train_loss: 0.6102
# epoch 66 average loss: 0.5923
# current epoch: 66 current mean recall per class: 0.3392, 0.665, 0.6802, 0.5844, 0.6977, 0.5929, 0.7416
# best mean recall: 0.6259 at epoch: 60
# ----------
# epoch 67/200
# batch 1/9, train_loss: 0.5701
# batch 2/9, train_loss: 0.5733
# batch 3/9, train_loss: 0.5825
# batch 4/9, train_loss: 0.5625
# batch 5/9, train_loss: 0.5918
# batch 6/9, train_loss: 0.7673
# batch 7/9, train_loss: 0.5754
# batch 8/9, train_loss: 0.5602
# batch 9/9, train_loss: 0.5404
# epoch 67 average loss: 0.5915
# ----------
# epoch 68/200
# batch 1/9, train_loss: 0.5775
# batch 2/9, train_loss: 0.5590
# batch 3/9, train_loss: 0.5510
# batch 4/9, train_loss: 0.5249
# batch 5/9, train_loss: 0.5384
# batch 6/9, train_loss: 0.5688
# batch 7/9, train_loss: 0.5517
# batch 8/9, train_loss: 0.7639
# batch 9/9, train_loss: 0.5887
# epoch 68 average loss: 0.5804
# saved new best metric model
# current epoch: 68 current mean recall per class: 0.4587, 0.6434, 0.653, 0.54, 0.7032, 0.6114, 0.7977
# best mean recall: 0.6296 at epoch: 68
# ----------
# epoch 69/200
# batch 1/9, train_loss: 0.5715
# batch 2/9, train_loss: 0.5149
# batch 3/9, train_loss: 0.5689
# batch 7/9, train_loss: 0.5466
# batch 8/9, train_loss: 0.6040
# batch 9/9, train_loss: 0.5506
# epoch 75 average loss: 0.5875
# ----------
# epoch 76/200
# batch 1/9, train_loss: 0.5674
# batch 2/9, train_loss: 0.5542
# batch 3/9, train_loss: 0.5674
# batch 4/9, train_loss: 0.5805
# batch 5/9, train_loss: 0.7607
# batch 6/9, train_loss: 0.5523
# batch 7/9, train_loss: 0.5398
# batch 8/9, train_loss: 0.5579
# batch 9/9, train_loss: 0.5375
# epoch 76 average loss: 0.5797
# current epoch: 76 current mean recall per class: 0.3562, 0.7164, 0.6954, 0.5261, 0.7418, 0.6269, 0.692
# best mean recall: 0.6590 at epoch: 74
# ----------
# epoch 77/200
# batch 1/9, train_loss: 0.5317
# batch 2/9, train_loss: 0.5468
# batch 3/9, train_loss: 0.5337
# batch 4/9, train_loss: 0.5305
# batch 5/9, train_loss: 0.5676
# batch 6/9, train_loss: 0.5680
# batch 7/9, train_loss: 0.5431
# batch 8/9, train_loss: 0.7546
# batch 9/9, train_loss: 0.5436
# epoch 77 average loss: 0.5688
# ----------
# epoch 78/200
# batch 1/9, train_loss: 0.4869
# batch 2/9, train_loss: 0.5737
# batch 3/9, train_loss: 0.5543
# batch 4/9, train_loss: 0.5582
# batch 5/9, train_loss: 0.5414
# batch 6/9, train_loss: 0.5573
# batch 7/9, train_loss: 0.5947
# batch 8/9, train_loss: 0.5175
# batch 9/9, train_loss: 0.7654
# epoch 78 average loss: 0.5722
# current epoch: 78 current mean recall per class: 0.4907, 0.6188, 0.6838, 0.5504, 0.6968, 0.6307, 0.7142
# best mean recall: 0.6590 at epoch: 74
# ----------
# epoch 79/200
# batch 1/9, train_loss: 0.7704
# batch 2/9, train_loss: 0.5722
# batch 3/9, train_loss: 0.5309
# batch 4/9, train_loss: 0.5660
# batch 5/9, train_loss: 0.5292
# batch 6/9, train_loss: 0.5514
# batch 7/9, train_loss: 0.5741
# batch 8/9, train_loss: 0.5168
# batch 9/9, train_loss: 0.5283
# epoch 79 average loss: 0.5710
# ----------
# epoch 80/200
# batch 1/9, train_loss: 0.5172
# batch 2/9, train_loss: 0.5726
# batch 3/9, train_loss: 0.5356
# batch 4/9, train_loss: 0.5420
# batch 5/9, train_loss: 0.5500
# batch 6/9, train_loss: 0.5736
# batch 7/9, train_loss: 0.5001
# batch 8/9, train_loss: 0.7571
# batch 9/9, train_loss: 0.5299
# epoch 80 average loss: 0.5642
# current epoch: 80 current mean recall per class: 0.4318, 0.6695, 0.6719, 0.6029, 0.698, 0.7042, 0.7068
# best mean recall: 0.6590 at epoch: 74
# ----------
# epoch 81/200
# batch 1/9, train_loss: 0.5083
# batch 2/9, train_loss: 0.5391
# batch 3/9, train_loss: 0.5536
# batch 4/9, train_loss: 0.5465
# batch 5/9, train_loss: 0.5902
# batch 6/9, train_loss: 0.5352
# batch 7/9, train_loss: 0.7564
# batch 8/9, train_loss: 0.5378
# batch 9/9, train_loss: 0.5653
# epoch 81 average loss: 0.5703
# ----------
# epoch 82/200
# batch 5/9, train_loss: 0.5280
# batch 6/9, train_loss: 0.5406
# batch 7/9, train_loss: 0.5377
# batch 8/9, train_loss: 0.5348
# batch 9/9, train_loss: 0.5183
# epoch 88 average loss: 0.5587
# current epoch: 88 current mean recall per class: 0.3966, 0.6653, 0.7306, 0.6536, 0.7453, 0.668, 0.7242
# best mean recall: 0.6699 at epoch: 86
# ----------
# epoch 89/200
# batch 1/9, train_loss: 0.5206
# batch 2/9, train_loss: 0.5502
# batch 3/9, train_loss: 0.5414
# batch 4/9, train_loss: 0.7475
# batch 5/9, train_loss: 0.5807
# batch 6/9, train_loss: 0.5456
# batch 7/9, train_loss: 0.5402
# batch 8/9, train_loss: 0.5028
# batch 9/9, train_loss: 0.5303
# epoch 89 average loss: 0.5621
# ----------
# epoch 90/200
# batch 1/9, train_loss: 0.5565
# batch 2/9, train_loss: 0.5311
# batch 3/9, train_loss: 0.5430
# batch 4/9, train_loss: 0.7594
# batch 5/9, train_loss: 0.5739
# batch 6/9, train_loss: 0.5533
# batch 7/9, train_loss: 0.5716
# batch 8/9, train_loss: 0.5934
# batch 9/9, train_loss: 0.5093
# epoch 90 average loss: 0.5768
# current epoch: 90 current mean recall per class: 0.4465, 0.7302, 0.7341, 0.5941, 0.7241, 0.623, 0.6996
# best mean recall: 0.6699 at epoch: 86
# ----------
# epoch 91/200
# batch 1/9, train_loss: 0.7543
# batch 2/9, train_loss: 0.5717
# batch 3/9, train_loss: 0.5189
# batch 4/9, train_loss: 0.5240
# batch 5/9, train_loss: 0.5600
# batch 6/9, train_loss: 0.5527
# batch 7/9, train_loss: 0.6005
# batch 8/9, train_loss: 0.5339
# batch 9/9, train_loss: 0.5402
# epoch 91 average loss: 0.5729
# ----------
# epoch 92/200
# batch 1/9, train_loss: 0.5798
# batch 2/9, train_loss: 0.5648
# batch 3/9, train_loss: 0.5459
# batch 4/9, train_loss: 0.5890
# batch 5/9, train_loss: 0.5425
# batch 6/9, train_loss: 0.5547
# batch 7/9, train_loss: 0.7819
# batch 8/9, train_loss: 0.5304
# batch 9/9, train_loss: 0.5495
# epoch 92 average loss: 0.5821
# saved new best metric model
# current epoch: 92 current mean recall per class: 0.424, 0.7188, 0.7147, 0.602, 0.7798, 0.7075, 0.75
# best mean recall: 0.6710 at epoch: 92
# ----------
# epoch 93/200
# batch 1/9, train_loss: 0.5610
# batch 2/9, train_loss: 0.5397
# batch 3/9, train_loss: 0.5397
# batch 4/9, train_loss: 0.7848
# batch 5/9, train_loss: 0.5848
# batch 6/9, train_loss: 0.5707
# batch 7/9, train_loss: 0.5565
# batch 8/9, train_loss: 0.5860
# batch 9/9, train_loss: 0.5731
# epoch 93 average loss: 0.5885
# ----------
# epoch 94/200
# batch 1/9, train_loss: 0.5593
# batch 2/9, train_loss: 0.7701
# batch 3/9, train_loss: 0.5470
# batch 4/9, train_loss: 0.5275
# batch 5/9, train_loss: 0.5200
# batch 6/9, train_loss: 0.5288
# batch 7/9, train_loss: 0.5685
# batch 8/9, train_loss: 0.5607
# batch 9/9, train_loss: 0.5788
# epoch 94 average loss: 0.5734
# current epoch: 94 current mean recall per class: 0.3699, 0.6629, 0.7139, 0.6186, 0.7079, 0.6311, 0.8517
# best mean recall: 0.6710 at epoch: 92
# ----------
# epoch 95/200
# batch 1/9, train_loss: 0.5669
# batch 2/9, train_loss: 0.5251
# batch 3/9, train_loss: 0.5346
# batch 4/9, train_loss: 0.7580
# batch 5/9, train_loss: 0.5638
# batch 6/9, train_loss: 0.5751
# batch 7/9, train_loss: 0.5277
# batch 8/9, train_loss: 0.5760
# batch 9/9, train_loss: 0.5391
# epoch 95 average loss: 0.5740
# ----------
# epoch 96/200
# batch 1/9, train_loss: 0.5534
# batch 2/9, train_loss: 0.5459
# batch 3/9, train_loss: 0.5723
# batch 4/9, train_loss: 0.5300
# batch 5/9, train_loss: 0.5809
# batch 6/9, train_loss: 0.7630
# batch 7/9, train_loss: 0.5204
# batch 8/9, train_loss: 0.5620
# batch 9/9, train_loss: 0.5881
# epoch 96 average loss: 0.5796
# saved new best metric model
# current epoch: 96 current mean recall per class: 0.4558, 0.744, 0.7121, 0.63, 0.7596, 0.6831, 0.7546
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 97/200
# batch 1/9, train_loss: 0.5051
# batch 2/9, train_loss: 0.5577
# batch 3/9, train_loss: 0.5617
# batch 4/9, train_loss: 0.7596
# batch 5/9, train_loss: 0.5151
# batch 6/9, train_loss: 0.5553
# batch 7/9, train_loss: 0.5506
# batch 8/9, train_loss: 0.5564
# batch 9/9, train_loss: 0.5320
# epoch 97 average loss: 0.5660
# ----------
# epoch 98/200
# batch 1/9, train_loss: 0.5608
# batch 2/9, train_loss: 0.5083
# batch 3/9, train_loss: 0.5236
# batch 4/9, train_loss: 0.5607
# batch 5/9, train_loss: 0.5801
# batch 6/9, train_loss: 0.7471
# batch 7/9, train_loss: 0.5710
# batch 8/9, train_loss: 0.5575
# batch 9/9, train_loss: 0.5383
# epoch 98 average loss: 0.5719
# current epoch: 98 current mean recall per class: 0.528, 0.6605, 0.7433, 0.5087, 0.6942, 0.7289, 0.7616
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 99/200
# batch 1/9, train_loss: 0.5433
# batch 2/9, train_loss: 0.5654
# batch 3/9, train_loss: 0.5186
# batch 4/9, train_loss: 0.5310
# batch 5/9, train_loss: 0.5463
# batch 6/9, train_loss: 0.5577
# batch 7/9, train_loss: 0.5312
# batch 8/9, train_loss: 0.7483
# batch 9/9, train_loss: 0.5502
# epoch 99 average loss: 0.5658
# ----------
# epoch 100/200
# batch 1/9, train_loss: 0.5418
# batch 2/9, train_loss: 0.5360
# batch 3/9, train_loss: 0.5432
# batch 4/9, train_loss: 0.5304
# batch 5/9, train_loss: 0.5524
# batch 6/9, train_loss: 0.5768
# batch 7/9, train_loss: 0.5446
# batch 8/9, train_loss: 0.7642
# batch 9/9, train_loss: 0.5657
# epoch 100 average loss: 0.5728
# current epoch: 100 current mean recall per class: 0.4168, 0.6603, 0.7231, 0.6118, 0.7621, 0.7112, 0.7951
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 101/200
# batch 1/9, train_loss: 0.5566
# batch 2/9, train_loss: 0.5158
# batch 3/9, train_loss: 0.5052
# batch 4/9, train_loss: 0.5401
# batch 5/9, train_loss: 0.5431
# batch 6/9, train_loss: 0.5491
# batch 7/9, train_loss: 0.5028
# batch 8/9, train_loss: 0.5902
# batch 9/9, train_loss: 0.7561
# epoch 101 average loss: 0.5621
# ----------
# epoch 102/200
# batch 1/9, train_loss: 0.7465
# batch 2/9, train_loss: 0.5465
# batch 3/9, train_loss: 0.5542
# batch 4/9, train_loss: 0.5310
# batch 5/9, train_loss: 0.5219
# batch 6/9, train_loss: 0.5438
# batch 7/9, train_loss: 0.5298
# batch 8/9, train_loss: 0.5360
# batch 9/9, train_loss: 0.5397
# epoch 102 average loss: 0.5610
# current epoch: 102 current mean recall per class: 0.4456, 0.6809, 0.6919, 0.6294, 0.7555, 0.6449, 0.8358
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 103/200
# batch 1/9, train_loss: 0.5205
# batch 2/9, train_loss: 0.5507
# batch 3/9, train_loss: 0.5306
# batch 4/9, train_loss: 0.5471
# batch 5/9, train_loss: 0.5508
# batch 6/9, train_loss: 0.5895
# batch 7/9, train_loss: 0.5011
# batch 8/9, train_loss: 0.7522
# batch 9/9, train_loss: 0.5245
# epoch 103 average loss: 0.5630
# ----------
# epoch 104/200
# batch 1/9, train_loss: 0.5658
# batch 2/9, train_loss: 0.5479
# batch 3/9, train_loss: 0.5737
# batch 4/9, train_loss: 0.5468
# batch 5/9, train_loss: 0.5517
# batch 6/9, train_loss: 0.5477
# batch 7/9, train_loss: 0.7592
# batch 8/9, train_loss: 0.5474
# batch 9/9, train_loss: 0.5447
# epoch 104 average loss: 0.5761
# current epoch: 104 current mean recall per class: 0.402, 0.6984, 0.7199, 0.6066, 0.7508, 0.7179, 0.7442
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 105/200
# batch 1/9, train_loss: 0.5314
# batch 2/9, train_loss: 0.5671
# batch 3/9, train_loss: 0.5382
# batch 4/9, train_loss: 0.5862
# batch 5/9, train_loss: 0.7727
# batch 6/9, train_loss: 0.5259
# batch 7/9, train_loss: 0.5446
# batch 8/9, train_loss: 0.5507
# batch 9/9, train_loss: 0.5405
# epoch 105 average loss: 0.5730
# ----------
# epoch 106/200
# batch 1/9, train_loss: 0.5041
# batch 2/9, train_loss: 0.4952
# batch 3/9, train_loss: 0.5203
# batch 4/9, train_loss: 0.5245
# batch 5/9, train_loss: 0.7431
# batch 6/9, train_loss: 0.5509
# batch 7/9, train_loss: 0.5315
# batch 8/9, train_loss: 0.5451
# batch 9/9, train_loss: 0.5558
# epoch 106 average loss: 0.5523
# current epoch: 106 current mean recall per class: 0.469, 0.701, 0.7282, 0.5874, 0.6564, 0.678, 0.7981
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 107/200
# batch 1/9, train_loss: 0.4976
# batch 2/9, train_loss: 0.5504
# batch 3/9, train_loss: 0.5457
# batch 4/9, train_loss: 0.5253
# batch 5/9, train_loss: 0.5401
# batch 6/9, train_loss: 0.5544
# batch 7/9, train_loss: 0.5157
# batch 8/9, train_loss: 0.7654
# batch 9/9, train_loss: 0.5352
# epoch 107 average loss: 0.5589
# ----------
# epoch 108/200
# batch 1/9, train_loss: 0.5500
# batch 2/9, train_loss: 0.5382
# batch 3/9, train_loss: 0.7616
# batch 4/9, train_loss: 0.4722
# batch 5/9, train_loss: 0.5276
# batch 6/9, train_loss: 0.5033
# batch 7/9, train_loss: 0.5545
# batch 8/9, train_loss: 0.5560
# batch 9/9, train_loss: 0.5822
# epoch 108 average loss: 0.5606
# current epoch: 108 current mean recall per class: 0.3887, 0.6372, 0.7453, 0.6506, 0.7906, 0.7117, 0.7993
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 109/200
# batch 1/9, train_loss: 0.5363
# batch 2/9, train_loss: 0.5338
# batch 3/9, train_loss: 0.5199
# batch 4/9, train_loss: 0.5300
# batch 5/9, train_loss: 0.5231
# batch 6/9, train_loss: 0.5363
# batch 7/9, train_loss: 0.4839
# batch 8/9, train_loss: 0.5457
# batch 9/9, train_loss: 0.7560
# epoch 109 average loss: 0.5517
# ----------
# epoch 110/200
# batch 1/9, train_loss: 0.6109
# batch 2/9, train_loss: 0.5164
# batch 3/9, train_loss: 0.5133
# batch 4/9, train_loss: 0.7542
# batch 5/9, train_loss: 0.5499
# batch 6/9, train_loss: 0.5019
# batch 7/9, train_loss: 0.5702
# batch 8/9, train_loss: 0.5548
# batch 9/9, train_loss: 0.5636
# epoch 110 average loss: 0.5706
# current epoch: 110 current mean recall per class: 0.4229, 0.6887, 0.6724, 0.509, 0.7059, 0.6985, 0.8623
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 111/200
# batch 1/9, train_loss: 0.5629
# batch 2/9, train_loss: 0.7485
# batch 3/9, train_loss: 0.5466
# batch 4/9, train_loss: 0.5331
# batch 5/9, train_loss: 0.4950
# batch 6/9, train_loss: 0.5330
# batch 7/9, train_loss: 0.5692
# batch 8/9, train_loss: 0.5078
# batch 9/9, train_loss: 0.5210
# epoch 111 average loss: 0.5575
# ----------
# epoch 112/200
# batch 1/9, train_loss: 0.5442
# batch 2/9, train_loss: 0.5449
# batch 3/9, train_loss: 0.5661
# batch 4/9, train_loss: 0.5323
# batch 5/9, train_loss: 0.5506
# batch 6/9, train_loss: 0.5409
# batch 7/9, train_loss: 0.7438
# batch 8/9, train_loss: 0.4806
# batch 9/9, train_loss: 0.5118
# epoch 112 average loss: 0.5572
# current epoch: 112 current mean recall per class: 0.4194, 0.6741, 0.697, 0.5832, 0.6964, 0.707, 0.8061
# best mean recall: 0.6770 at epoch: 96
# ----------
# epoch 113/200
# batch 1/9, train_loss: 0.5787
# batch 2/9, train_loss: 0.5167
# batch 3/9, train_loss: 0.5280
# batch 4/9, train_loss: 0.5256
# batch 5/9, train_loss: 0.5630
# batch 6/9, train_loss: 0.5424
# batch 7/9, train_loss: 0.5278
# batch 8/9, train_loss: 0.7406
# batch 9/9, train_loss: 0.5366
# epoch 113 average loss: 0.5621
# ----------
# epoch 114/200
# batch 1/9, train_loss: 0.5190
# batch 2/9, train_loss: 0.5156
# batch 3/9, train_loss: 0.5416
# batch 4/9, train_loss: 0.5406
# batch 5/9, train_loss: 0.5172
# batch 6/9, train_loss: 0.5717
# batch 7/9, train_loss: 0.5589
# batch 8/9, train_loss: 0.7594
# batch 9/9, train_loss: 0.5417
# epoch 114 average loss: 0.5629
# saved new best metric model
# current epoch: 114 current mean recall per class: 0.4733, 0.6955, 0.7337, 0.5957, 0.7602, 0.6797, 0.8627
# best mean recall: 0.6858 at epoch: 114
# ----------
# epoch 115/200
# batch 1/9, train_loss: 0.5770
# batch 2/9, train_loss: 0.5074
# batch 3/9, train_loss: 0.5357
# batch 4/9, train_loss: 0.5517
# batch 5/9, train_loss: 0.5277
# batch 6/9, train_loss: 0.5403
# batch 7/9, train_loss: 0.7656
# batch 8/9, train_loss: 0.5217
# batch 9/9, train_loss: 0.5290
# epoch 115 average loss: 0.5618
# ----------
# epoch 116/200
# batch 1/9, train_loss: 0.5169
# batch 2/9, train_loss: 0.5653
# batch 3/9, train_loss: 0.5460
# batch 4/9, train_loss: 0.5162
# batch 5/9, train_loss: 0.5322
# batch 6/9, train_loss: 0.5183
# batch 7/9, train_loss: 0.7652
# batch 8/9, train_loss: 0.5432
# batch 9/9, train_loss: 0.5691
# epoch 116 average loss: 0.5636
# current epoch: 116 current mean recall per class: 0.406, 0.6831, 0.7582, 0.5704, 0.7617, 0.6444, 0.7105
# best mean recall: 0.6858 at epoch: 114
# ----------
# epoch 117/200
# batch 1/9, train_loss: 0.5377
# batch 2/9, train_loss: 0.5285
# batch 3/9, train_loss: 0.5070
# batch 4/9, train_loss: 0.4993
# batch 5/9, train_loss: 0.7478
# batch 6/9, train_loss: 0.5169
# batch 7/9, train_loss: 0.5566
# batch 8/9, train_loss: 0.5177
# batch 9/9, train_loss: 0.5021
# epoch 117 average loss: 0.5460
# ----------
# epoch 118/200
# batch 1/9, train_loss: 0.5330
# batch 2/9, train_loss: 0.5288
# batch 3/9, train_loss: 0.5016
# batch 4/9, train_loss: 0.5342
# batch 5/9, train_loss: 0.5401
# batch 6/9, train_loss: 0.5243
# batch 7/9, train_loss: 0.5597
# batch 8/9, train_loss: 0.5867
# batch 9/9, train_loss: 0.7585
# epoch 118 average loss: 0.5630
# saved new best metric model
# current epoch: 118 current mean recall per class: 0.4961, 0.755, 0.759, 0.6393, 0.7422, 0.634, 0.816
# best mean recall: 0.6917 at epoch: 118
# ----------
# epoch 119/200
# batch 1/9, train_loss: 0.5538
# batch 2/9, train_loss: 0.5284
# batch 3/9, train_loss: 0.5293
# batch 4/9, train_loss: 0.7644
# batch 5/9, train_loss: 0.5002
# batch 6/9, train_loss: 0.5190
# batch 7/9, train_loss: 0.5506
# ...
# batch 5/9, train_loss: 0.5128
# batch 6/9, train_loss: 0.4784
# batch 8/9, train_loss: 0.5361
# batch 9/9, train_loss: 0.5135
# epoch 199 average loss: 0.5420
# ----------
# epoch 200/200
# batch 1/9, train_loss: 0.5360
# batch 2/9, train_loss: 0.5134
# batch 3/9, train_loss: 0.5285
# batch 4/9, train_loss: 0.4836
# batch 5/9, train_loss: 0.4821
# batch 6/9, train_loss: 0.5038
# batch 7/9, train_loss: 0.5454
# batch 8/9, train_loss: 0.5260
# batch 9/9, train_loss: 0.7526
# epoch 200 average loss: 0.5413
# current epoch: 200 current mean recall per class: 0.4656, 0.7066, 0.7729, 0.6327, 0.7679, 0.7324, 0.8167
# best mean recall: 0.7153 at epoch: 174
# 2024/10/02 00:37:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# ##### Let's Go Straight to Evaluating the Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=len(root.pickable_objects)+1,
    channels=(48, 64, 80, 80),
    strides=(2, 2, 1),
    num_res_units=1,
).to(device)

model.load_state_dict(torch.load("best_metric_model.pth", weights_only=True))
# Out:
# cuda
# <All keys matched successfully>

# %%
def inference(model, input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=(96, 96, 96),
            sw_batch_size=4,  # one window is proecessed at a time
            predictor=model,
            overlap=0.5,
        )

    with torch.cuda.amp.autocast():
        return _compute(input)

# %%
# define pre transforms
pre_transforms = Compose(
    [   EnsureChannelFirstd(keys=["image"], channel_dim="no_channel"),
        NormalizeIntensityd(keys=["image"]),
])


test_ds = CacheDataset(data=test_files, transform=pre_transforms)
test_loader = DataLoader(test_ds, 
                         batch_size=4, 
                         shuffle=False, 
                         num_workers=4, 
                         pin_memory=torch.cuda.is_available())
# Out:
# Loading dataset: 100%|████████████████████████████| 2/2 [00:02<00:00,  1.48s/it]

# %%
from monai.data import decollate_batch
from tqdm import tqdm
from monai.transforms import (
    Compose, 
    NormalizeIntensityd,
    EnsureChannelFirstd, 
    ScaleIntensityRanged, 
    Orientationd,  
    Resized, 
    Activationsd,
    Invertd,
    AsDiscreted
)

post_transforms = Compose([
            Activationsd(keys="pred", softmax=True),
            AsDiscreted(keys="pred", argmax=True)
])

predictions = []
with torch.no_grad():
    for data in tqdm(test_loader):
        tomogram = data['image'].to(device)  # only support batch=1 and channel first
        data["pred"] = inference(model, tomogram)
        data = [post_transforms(i) for i in decollate_batch(data)]
        for b in data:
            predictions.append(b['pred'].squeeze(0).numpy(force=True))
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/tmp/ipykernel_1119924/339001617.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# 100%|█████████████████████████████████████████████| 1/1 [00:19<00:00, 19.87s/it]

# %%
import matplotlib.pyplot as plt

tomo_index = 0

# Plot the images
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Tomogram')
plt.imshow(test_files[tomo_index]['image'][60], cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Ground Truth Picks')
plt.imshow(test_files[tomo_index]['label'][60], cmap='viridis')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Predicted Mask')
plt.imshow(predictions[tomo_index][60],cmap='viridis')
plt.axis('off')

plt.tight_layout()
plt.show()
